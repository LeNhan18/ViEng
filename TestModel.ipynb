# %% [markdown]
# <a href="https://colab.research.google.com/github/LeNhan18/ViEng/blob/main/TestModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch transformers peft datasets accelerate bitsandbytes
# !pip install trl

# %%
# !pip install accelerate

# %%
from transformers import AutoModelForCausalLM, BitsAndBytesConfig
quantizations_config = BitsAndBytesConfig(load_in_4bit=True,bnb_4bit_compute_dtype=torch.float16)
model = AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct",quantizations_config=quantizations_config,device ="auto")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_157/3026643153.py in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, BitsAndBytesConfig
# ----> 2 quantizations_config = BitsAndBytesConfig(load_in_4bit=True,bnb_4bit_compute_dtype=torch.float16)
#       3 model = AutoModelForCausalLM.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct",quantizations_config=quantizations_config,device ="auto")
#
# NameError: name 'torch' is not defined
